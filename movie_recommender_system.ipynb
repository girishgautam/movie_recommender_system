# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd
import numpy as np

# %%
# Dowlnoad data - from kaggle - https://www.kaggle.com/datasets/tmdb/tmdb-movie-metadata
movies_df = pd.read_csv('tmdb_5000_movies.csv')
credits_df = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies_df.shape
# Out:
# (4803, 20)

# %%
credits_df.shape
# Out:
# (4803, 4)

# %%
movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
credits_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
# merge both csv's
new_movies_df = movies_df.merge(credits_df, on='title')

# %%
new_movies_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  ... runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   169.0
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...   148.0
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...  ...   165.0
# 4        [{"name": "Walt Disney Pictures", "id": 2}]  ...   132.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
# 2  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3           [{"iso_639_1": "en", "name": "English"}]  Released
# 4           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title vote_average vote_count movie_id  \
# 0                                    Avatar          7.2      11800    19995
# 1  Pirates of the Caribbean: At World's End          6.9       4500      285
# 2                                   Spectre          6.3       4466   206647
# 3                     The Dark Knight Rises          7.6       9106    49026
# 4                               John Carter          6.1       2124    49529
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %%
new_movies_df.shape
# Out:
# (4809, 23)

# %%
new_movies_df.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
#
# [1 rows x 23 columns]

# %%
# remove columns that are not textual and are not as importannt for comparison- use your intution for columns to keep .
columns_to_keep = ['id', 'title', 'genres', 'keywords', 'overview', 'cast', 'crew']
new_movies_df = new_movies_df[columns_to_keep]

# %%
new_movies_df.head(1)
# Out:
#       id   title                                             genres  \
# 0  19995  Avatar  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
# check for null values. as null values are only 3 and not a big number, drop them instead of imputing them.
#Check for duplicates and drop them as they would be same movies.
new_movies_df.isnull().sum()
# Out:
# id          0
# title       0
# genres      0
# keywords    0
# overview    3
# cast        0
# crew        0
# dtype: int64

# %%
new_movies_df.dropna(inplace=True)

new_movies_df = new_movies_df.drop_duplicates(subset=['title', 'crew'], keep='first')

# %%
import ast
# import json

# %% [markdown]
# ##### Textual data in geners, keywords, cast and crew are list which are strings. So need to convert them into a list first and then process them accordingly.
# ##### Use either json.loads or ast.literal.eval to convert string into list and then write a function to extract name from the list

# %%
# type(json.loads(new_movies_df['genres'][0]))
type((new_movies_df['genres'][0]))
# Out:
# str

# %%
def clean(series):
    '''
    function to convert string and 
    extract name from the list
    '''
    list = []
    for i in ast.literal_eval(series):
        list.append(i['name'])
    return list

# %%
new_movies_df['genres'] = new_movies_df['genres'].apply(clean)

new_movies_df['keywords'] = new_movies_df['keywords'].apply(clean)

# %%
def clean_2(series):
    '''
    decided to take just the 3 top actors from the
    cast for our comparison
    '''
    list = []
    count = 0
    for i in ast.literal_eval(series):
        if count != 3:
            list.append(i['name'])
            count += 1
        else:
            break
    return list

# %%
new_movies_df['cast'] = new_movies_df['cast'].apply(clean_2)

# %%
new_movies_df['cast'][0]
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver']

# %%
def find_director(series):
    '''
    decided to take just the director
    from the crew for our comparison.
    '''
    
    list = []
    for i in ast.literal_eval(series):
        if i['job'] == 'Director':
            list.append(i['name'])
            break
    return list

# %%
new_movies_df['crew'] = new_movies_df['crew'].apply(find_director)

# %%
# overview column has textual data in string, convert that into list
new_movies_df['overview'] = new_movies_df['overview'].apply(lambda x: x.split())

# %%
new_movies_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %%
new_movies_df.shape
# Out:
# (4800, 7)

# %% [markdown]
# ##### Removed spaces from the names of actors and directors so when we embed these they can be embbeded as one person. for ex Sam Worthington and Sam Mendes could be distinguished as 2 different people rather than three entities Sam, Worthington and Mendes. Similarly joined words in geners and keywords.

# %%
new_movies_df['genres'] = new_movies_df['genres'].apply(lambda x: [i.replace(' ', '') for i in x])
new_movies_df['keywords'] = new_movies_df['keywords'].apply(lambda x: [i.replace(' ', '') for i in x])
new_movies_df['cast'] = new_movies_df['cast'].apply(lambda x: [i.replace(' ', '') for i in x])
new_movies_df['crew'] = new_movies_df['crew'].apply(lambda x: [i.replace(' ', '') for i in x])

# %%
new_movies_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %%
# made a new column by concatenation all textual data
new_movies_df['tags'] = new_movies_df['genres'] + new_movies_df['keywords'] + new_movies_df['overview'] + new_movies_df['cast'] + new_movies_df['crew']

# %%
new_movies_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4  [Action, Adventure, ScienceFiction, basedonnov...

# %%
# deleted the text columns as we only need tags column that has all the information needed
final_df = new_movies_df[['id', 'title', 'tags']]

# %%
final_df.head()
# Out:
#        id                                     title  \
# 0   19995                                    Avatar
# 1     285  Pirates of the Caribbean: At World's End
# 2  206647                                   Spectre
# 3   49026                     The Dark Knight Rises
# 4   49529                               John Carter
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4  [Action, Adventure, ScienceFiction, basedonnov...

# %%
# final_df.tags.to_list()

# %%
# converted tags column into string and also into lower font.
final_df['tags'] = final_df['tags'].apply(lambda x: ' '.join(x).lower())
# Out:
# /tmp/ipykernel_447/1665728877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['tags'] = final_df['tags'].apply(lambda x: ' '.join(x).lower())

# %%
list(final_df[final_df['title'] == 'Avatar']['tags'])
# Out:
# ['action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. samworthington zoesaldana sigourneyweaver jamescameron']

# %% [markdown]
# # Stemming & Vectorisation

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

# %%
def stemming(series):
    list = []
    for i in series.split():
        list.append(ps.stem(i))
    return ' '.join(list)

# %%
final_df['tags'] = final_df['tags'].apply(stemming)
# Out:
# /tmp/ipykernel_447/1204883231.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df['tags'] = final_df['tags'].apply(stemming)

# %%
# using Bag of Words to vectorise, maximum words to be used from corpous = 5000 and used stop words.
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.fit_transform(final_df['tags']).toarray()

# %%
feature_names = cv.get_feature_names_out()
for feature in feature_names:
    print(feature)
# Out:
# 00
# 000
# 10
# 11
# 12
# 14
# 16
# 18
# 1970s
# 1974
# 1990
# 200
# 27
# 30
# 300
# 50
# 60
# 60s
# aarontaylor
# abeautiful
# aboveall
# abram
# accidentally
# action
# actionadventureromancesciencefictionthrillerbasedonnovelmassmurderdystopiagenocidealieninvasionduringcreditsstingerinterspeciesromancealienparasitesaparasiticaliensoulisinjectedintothebodyofmelaniestryder
# actually
# ada
# adam
# adams
# adaptedfromthenovel
# aditya
# adown
# adrug
# adventure
# adventurefantasyactionelvesorcsmiddle
# afast
# afree
# afterall
# afterhisfather
# afterservinghisfiveyearjailsentence
# againstallodds
# aggie
# agroupofco
# ahigh
# ahusband
# alaska
# alecbaldwin
# alex
# alice
# alike
# alongtheway
# alovetriangle
# amador
# amanda
# america
# american
# americangirl
# americanwar
# americanzion
# amiddle
# amp
# amy
# an11
# andagain
# andall
# andeachother
# anderson
# andhe
# andhedoesn
# andhisfamily
# andhisfiancée
# andisn
# andit
# andjack
# andjin
# andnowhe
# andnowshe
# andonlyonemancanstophim
# andself
# andshe
# andthat
# andthecouple
# andthemafia
# andthey
# andwhy
# andy
# anex
# angela
# anger
# annafaris
# anne
# annemosslillywachowski
# anthonyhopkins
# antonio
# antoniobanderascarlaguginoalexapenavegarobertrodriguez
# antonyelchin
# apocalypticfuture
# apocalypticworld
# areal
# artist
# asaresult
# aself
# asexy
# asmall
# asmuggler
# aspace
# asshecomestobecalled
# asshedesperatelytriestoholdeveryonetogether
# asthenightprogresses
# atfirst
# athome
# atthesametime
# atwo
# avildsen
# awantedman
# awell
# awild
# ayoungman
# baby
# bannon
# barry
# bart
# basedonactualevents
# basedonatruestory
# basketball
# baxley
# becausehehasn
# beforelong
# beforeyoucansay
# benkingsley
# benstiller
# bestfriends
# betrayal
# bettemidler
# big
# billy
# blaustein
# boring
# bornagain
# boss
# boyfriend
# boyfriendex
# bradleycooperedhelmszachgalifianakistoddphillip
# breakingupwards
# breathingdragon
# briano
# brien
# brilliant
# brook
# brother
# buddylove
# bushmichaelmoor
# butbeforelong
# buthe
# buthedoesn
# butit
# butitisn
# butler
# butnow
# butnowhe
# butshe
# butsoon
# butthat
# butthere
# butthey
# butthingsdon
# butwhenhe
# bychance
# bythewood
# cal
# california
# called
# calvin
# campbell
# capt
# car
# carl
# carmen
# carol
# carrie
# carter
# caruso
# catherinezeta
# cebe
# chandor
# charlie
# chazzpalminteri
# cher
# children
# choimin
# chowyun
# chriso
# christian
# chu
# circuit
# clay
# clonewars
# close
# cmdr
# cohen
# collection
# com
# comedy
# comedydocumentarystand
# connor
# cool
# cosmato
# courage
# craigt
# crane
# crossed
# cruise
# cubagoodingjr
# danielday
# danielradclifferupertgrintemmawatsonchriscolumbu
# danielradclifferupertgrintemmawatsondavidy
# danny
# dannydevito
# dannydyer
# dannyglover
# darcy
# daughter
# davi
# david
# davidarquettenevecampbellcourteneycoxwescraven
# davidhewlett
# day
# dc
# death
# demons
# derek
# desperate
# destruction
# determination
# diane
# dies
# dil
# dillon
# disappears
# discovery
# doc
# doorneighbor
# doubt
# dr
# drag
# drama
# dramapunkindependentfilmcomingofageteenagegirlalcoholicfatherdennishopperisahard
# dramaromanceloveofone
# drinkingtruckdriverwholosescontrolofhistruckundertheinfluenceandslamsitintoabusloadofscreamingchildren
# drug
# drugs
# duchovny
# duringthenight
# dylano
# eachother
# earth
# eddie
# edmund
# eeyore
# eliasmerhig
# elijahwoodianmckellenviggomortensenpeterjackson
# ella
# elli
# elmariachi
# emily
# emmathompson
# enemies
# england
# er
# erica
# esteem
# ethanhawke
# eve
# evenifit
# eventually
# evenworse
# evil
# ewanmcgregornatalieportmanhaydenchristensengeorgeluca
# ex
# expectations
# fallsill
# family
# familybusiness
# familypainfullyprovestobedoomed
# fantasyactiondoublelifedccomicsdualidentitychemicalcrimefighterfictionalplacegothamcitysuperherosuperpowersthedarkknightofgothamcitybeginshiswaroncrimewithhisfirstmajorenemybeingtheclownishlyhomicidaljoker
# female
# ferrell
# fi
# finalcut
# finally
# fiveyearslater
# fixer
# food
# foot
# forever
# forgiveness
# forhelp
# formerblack
# formsabondwithherhostandsetsouttoaidotherfreehumans
# forsixmonths
# fortunately
# foryears
# foxchristopherlloydleathompsonrobertzemecki
# foxgeenadavishughlaurierobminkoff
# frank
# frankenstein
# freddieprinzejr
# free
# freeman
# friend
# friends
# friendship
# fun
# funny
# furious
# future
# gangster
# garygray
# gavra
# genehackman
# george
# georgeclooneybradpittmattdamonstevensoderbergh
# georgia
# girl
# girlfriend
# god
# gonzo
# good
# gothamcity
# paddyconsidinegarystretchtobykebbellshanemeadow
# paddyconsidinejuliastilescarolinedhavernasjamiethrav
# padmé
# pagetbrewsterneilbartonerichoffmanphilipzlotorynski
# pagethenseducesthem
# pai
# paidassassinsworkingforrivalorganisations
# paidinternationalsearchforararecopyofthebook
# paidtobepartofhislife
# paigeandedwardcomefromtwodifferentworlds
# paigeturcodavidwarnermichelansistimichaelpressman
# paigeturcostuartwilsonsabshimonostuartgillard
# paikea
# pailoveskoromorethananyoneintheworld
# pain
# pairedwithapartnerasinexperiencedasheis
# pairedwithsimplecountrycop
# pakula
# paleoclimatologist
# palestinians
# palmsstarttosweatandadarkpsychologicalmatchinhisheadbegins
# palominoisreturningtoearthafterafruitless18
# palstoaccomplishaseeminglyimpossiblefeat
# pam
# pamelaandersonjennymccarthymarnyengdavidzuck
# pamgriersamuell
# pamperedtasmin
# pandaemoniumevokeslate
# panicanddespair
# panicgripscalifornia
# pannalin
# pantomimeandsubtitles
# paolo
# parallelstorylinesintertwineandunfoldtwistsagainstthebackdropofthedangeroushumantraffickingworld
# paralyzedinthevietnamwar
# paranoiaanddistrustwhenover
# paranormalactivities
# paranormalenthusiastseringilbertandabbyyates
# paranormallegends
# parentalandothercrises
# parentingacomedy
# parents
# parentswholovehim
# paris
# parisandamsterdam
# parkerposeydannydevitopaulruddbillyk
# parkerstillcan
# parkgirlwhoistoldtolookforthreekingsbyaphonepsychic
# parkoverallveronicacartwrightfreddieprinzejr
# parmindernagrakeiraknightleyjonathanrhysmeyersgurinderchadha
# parrishagrees
# parrishhaslovinglydevelopedphotosfortheyorkinfamilysincetheirsonwasababy
# parrotmon
# parryshenjasontobinsungkangjustinlin
# parson
# partaintobehoop
# partgovernmentintimidationtactic
# participatedinsecretexperiments
# participatinginnationalsurfcompetitionswithherbestfriendalana
# participationincouplestherapysessionsismandatory
# particularlybythemormon
# particularlyhisdaughter
# parties
# partmeditationonthevanishingwondersofthesub
# partner
# partnerlearnsofthescheme
# partnerofquick
# partofamassiveoperationtoextractvitalresourcesafterdecadesofwarwithaterrifyingthreatknownasthescavs
# partofaninternationalnavalcoalitionwhichbecomestheworld
# partofaresistancemovement
# partofaworldwidegeophysicalteaminvestigatingtheeffectontheearthofradiationfromunprecedentedsolarstorms
# partofmeexposesthehardwork
# partofmerevealsthesinger
# partoftheagreementwasthatthevichygovernmentwouldassistwiththe
# partthriller
# parttwistedentertainment
# partyboywhoonlylooksforwardtobeddinganewguyeverynight
# partyingensues
# partyinghighschoolsenior
# partyingroommatecooperfrederickson
# partyopportunities
# partyrevelry
# parvezkhan
# passinghimselfoffasasinglefather
# passion
# passionandpride
# passionate
# passionatemusicianglennhollandtakesadayjobasahighschoolmusicteacher
# passionaterelationship
# passioncoffeegrowersindenunciationayoungmanisplungedintoalifeofsubterfuge
# passiveresistance
# passthebarfbag
# pastandfuture
# pastorfatherandpursuespop
# patchofheaven
# pathealyethanembrysarapaxtone
# patientandapparentlythoughtful
# patmoritaericrobertsgailkimbabarahm
# patriarchborganhasthreesons
# patriciaarquette
# patriciaarquettegabrielbyrnejonathanprycerupertwainwright
# paulnewmanrobertredfordkatharinerossgeorgeroyhil
# paulnewmanrobertredfordrobertshawgeorgeroyhil
# paulnewmantomcruisemaryelizabethmastrantoniomartinscorses
# paulopensupanewcampclosetotheinfamoussite
# paulrappenau
# paulrappeneau
# paulriversanailingmathematicianlovelesslymarriedtoanenglishémigré
# paulrudd
# paulruddadambrodyjonhammdavidwain
# paulruddamypoehlerbillhaderdavidwain
# paulruddelizabethbankszooeydeschaneljesseperetz
# paulruddjasonsegelrashidajonesjohnhamburg
# paulruddjenniferanistonjustintherouxdavidwain
# paulruddlesliemannjasonsegeljuddapatow
# paulruddmichaeldouglasevangelinelillypeytonre
# paulruddpaulgiamattisallyhawkinsphilmorrison
# paulrust
# paulschneiderzooeydeschaneldannymcbridedavidgordongreen
# paulscofieldwendyhillerleomckernfredzinnemann
# paulsimon
# paulsorvinochazzpalminterimichaelrapaportdavidrodriguez
# paulwalker
# paulwalkerbrucegreenwoodmoonbloodgoodfrankmarshal
# paulwalkercameronbrightverafarmigawaynekram
# paulwalkerdavidbellerzacamilledelamarr
# paulwalkerfranceso
# paulwalkerjessicaalbascottcaanjohnstockwel
# paulwalkerjohnashtondennishoppersteveboyum
# paulwalkerlaurencefishburneoliviawildejohnherzfeld
# paulwalkertyresegibsonevamendesjohnsingleton
# paulwalkervindieselmichellerodriguezrobcohen
# paulwarugerardjohnston
# paulzanepilzer
# paws
# payback
# payinghouse
# paysavisittothefamily
# pazdelahuerta
# pazdelahuertakatrinabowdenkathleenturnerdouglasaarniokoski
# pcnicholasangelisgood
# peace
# peaceful
# pearce
# peasantmathayusishiredtoexactrevengeonthepowerfulmemnonandthesorceresscassandra
# peckedfamilyman
# pedal
# pediatriciansteveedison
# pedophiliasisterpartnershipstalkersecretloveindependentfilmrelationshipextramaritalaffairfamilyconflictunhappinessthelivesofmanyindividualsconnectedbythedesireforhappiness
# peggyashcroft
# peléfranzbeckenbauercarlosalbertopaulcrowd
# penelopeannmillertomsizemorelindahuntpeterhyam
# penelopecruz
# penguins
# pennbadgley
# pennilessdrifter
# pennsylvania
# pennsylvaniawhenpassengersfoiledtheterroristplot
# penny
# pennypingletonauditiontobeonthecornycollinsshow
# pent
# penélopecruz
# penélopecruzcarmenmauraloladueñaspedroalmodóvar
# penélopecruzmartinfreemangwynethpaltrowjakepaltrow
# penélopecruzmurilobeniciomarkfeuersteinfinatorr
# penélopecruzsalmahayekdwightyoakamjoachimrøn
# people
# peoplearecomingbetweenhertruefate
# peoplearedrawnoutsidelikemothstoaflamewhereanextraterrestrialforcethreatenstoswallowtheentirehumanpopulationoffthefaceoftheearth
# peopleareleftwonderingifthereisabetterway
# peopleareoverworkedandunderpaid
# peoplearesufferingfromwarnerves
# peoplebeingbombardedbymediaandgovernmentwithmessageslike
# peoplefoundthemselvesinasocietyspirallingintoterriblechaos
# peoplein2008hungeredforaleaderwhowoulduniteandliftusfromeconomicturmoilandwar
# peoplewhoarelivingonthisplanethaveremainedatthestonelevelofthe20thcentury
# peoplewholiveheredonotresembleanyotherpeoplewhichthetravelersawbeforethat
# perception
# pittedagainstaclassofboisterousmoppetswhoseanticstryhispatienceandtesthismettle
# pittedagainsthighly
# pittinghimagainstanemperorfromthe2
# piyapasbhirombhakdisarunyuwongkrachangchatchaiplengpanichchatrichalermyukol
# placeandabidebythethreelawsofrobotics
# placesacurseuponhisnewborninfantaurora
# plaguedbyadreadedstutterandconsideredunfittobeking
# plaguedbyhorrificnightmaresandthedisappearanceofherfather
# plaguedranch
# plainview
# plainviewgainsthecooperationofalmostallthelocalswithloftypromisestobuildschoolsandcultivatethelandtomaketheircommunityflourish
# planaheistthatwilloutdotheirpreviousprankandmakethemlocallegends
# planetg
# plannedtriptothelandofthepharoahs
# plans
# plansaheistagainstthethreelocalfarmers
# planstomergewiththebestteamsoftheabaattheendoftheseason
# planstotakeoverearthfromtheinsidebysendinganoperative
# planstowedolivervance
# plantatflint
# plassegregmottola
# plassejeffwadlow
# plassematthewvaughn
# platedkillingmachineintheblinkofaneye
# platinumrapsuperstarsredmanandmethodmanstarasjamalandsilas
# playattemptstogetrichquickinthemusicbusinesswhilekidfacesthechallengesofcollege
# playbook
# playboy
# playedbyallenhimself
# playedbygenevieveo
# playedbyhughjackman
# playedbysinger
# playedbyvanwarmerdam
# playedbywillemdafoe
# playerbaseballteamtocompeteagainststandardlittleleaguesquads
# playerswhonevergotachance
# playingalcoholic
# playingbeau
# playinggirlfriend
# playinghealthfoodstoreproprietor
# playingskills
# playingthemusicthatdefinesagenerationandstandinguptoagovernmentthatwantedcontrolofpopularcultureviathebritishbroadcastingcorporation
# playleavetheirneighborhoodandentertheworldofadulthoodandhighereducation
# playmusic
# playrumpus
# playsoutagainstabackgroundoflove
# playstheroleofhernextcustomerashenegotiateswiththepimpfortheuseofthechild
# playwrightlillianhellmanundertakesadangerousmissiontosmugglefundsintonazigermany
# playwrightuptohisearsindebt
# pleaselookafterthisbear
# pleasurewasabusinessandbusinesswasbooming
# pleasuringandfindsanunusualbed
# pledge
# plex
# plotsandfantasizes
# plotsrevengewhenhelearnshe
# plottolurehimawayfromgabriella
# plucksshanefromtheseaoffacesclamoringtogetinsidehisclub
# plumbersfrombrooklyn
# plumbingthedepthsofajewishworldlockedincrisisandonthecuspofprofoundchange
# plummer
# plumpeddowndonjuan
# plungeshimintothecenterofaninternationalcrisisofterrifyingmagnitude
# plungingintoadaringschemeofduplicity
# plus
# plusanicecommissionforhimself
# plusaprovocativetaleofjealousyandbetrayalcombinetocreatethiscontroversialmodern
# plusinterviewswiththesurvivingastronauts
# plusrecentlyrediscoveredpersonalscrapbooks
# plusthesecretengine
# plutonash
# pocahontasisanativeamericanwomanwhosefatherhasarrangedforhertomarryhervillage
# pochenkohastimetotellbishopaboutsomeconspiracyinthewhitehousebutthenimmediatelygetskilledbyanassassin
# poet
# pointbreak
# polarmallsecurityguardronniebarnhardtiscalledintoactiontostopaflasherfromturningshopper
# policechiefwyattrash
# policediscovergruesomemurdersonthecargoshipthatbroughtthecratestotheusandthenanothermurderinthemuseumitself
# policeforceofthe1950susedifferingmethodstouncoveraconspiracybehindtheshotgunslayingsofthepatronsatanall
# policeofficer
# policeofficerintersectastheystruggletoresisttheirvulnerabilitiesandtemptations
# polishpianistwhoduringthesecondworldwarlivedandhidmiraculouslyinwarsawafterhavinggonethroughaterribletragedy
# politeand
# politicalintrigueandbloodyholywarsduringthecrusades
# politicalpostersinnewyork
# politician
# politiciansandjournalists
# politics
# politicsexplodingbuildingsuspensemysterymafiaconspiracylawyercrimeprivacysurveillancebaltimoremarylandsecrethideouthotshotwashingtonlawyer
# pollardtonymaylam
# pollockbeganadownwardspiral
# pollybeginstosuspectthatsomethingisamissbetweenroseandgeorge
# pollyprinceisirresistibleasafree
# pompeiitellstheepicstoryofmilo
# pomustfacetwohugelyepic
# ponyousesherfather
# poochandcougar
# pooh
# poohconvincestigger
# poormanlovedisastertragicloveclassdifferencesimaxstarcrossedloverssteeragesalvagerichsnob3d1910s84yearslater
# poorplanningandacall
# poorrodcannotevengetanyrespectfromhisstepfather
# poorwomanbusinessmanwesleydeedsisjoltedoutofhisscriptedlifewhenhemeetslindsey
# pootiemustlearntofindhimselfanddefeattheevilcorporationforalltheyoungblackchildrenofamerica
# popestablishmentswithname
# popeye
# popular
# population
# pornofilms
# porter
# portgambleisbeingoverrunwithbraineaters
# portiaderossichristinariccijesseeisenbergwescraven
# portiadoubleday
# portiafindsherselfbendingtherulesforjeremiah
# portrayedbysupermodelvanessahessler
# posesasaninnocentsmall
# posingaroomingpredicamentfortwofresharrivals
# posingasahuman
# posingasaman
# posingasapriest
# posingasbigmommaandcharmaine
# possessingvarioussupernaturalpowers
# possiblyautobiographicalofmirandajuly
# postalsystemwhotransformthemselvesintoaneliteteamoflost
# potentiallydeadlydecisionsfacedbyordinaryciviliansinanoccupiedcountry
# potterfindsthemisplacedmoney
# potterfromtakingovertheentiretown
# potterstealsthewillgrantingtitletothehouse
# potty
# poulinmaximgaudettedenisvilleneuv
# poundframedowntosizeandwinherheart
# pounding
# poundingraceagainsttimeasthegroupfacesoffagainsthordesofblood
# poundvillainofanarcadevideogamenamedfix
# powell
# powelltospeakagainandmaybeevenstandjudgmentatatrialforhisreleasefromprisonofmentalcases
# power
# powercareerandthewomanheloves
# poweredbusinesswomanandbuddingnovelist
# poweredkillers
# poweredtickerthatrequiresregularjoltsofelectricitytokeepworking
# poweredweapons
# powerful
# powerfulcriminal
# powerfultransformermenacesetsearthinhiscross
# powerfulwitchqueen
# powerlawyers
# powers
# prabhasranadaggubatitamannabhatias
# prabhudevaganeshacharyakaykaymenonremod
# pranksandskits
# pre
# precious
# precociouslittlesisterandnewgirlfriend
# precociousorphanlyrabelacquatradeshercarefreeexistenceroamingthehallsofjordancollegeforanotherworldlyadventureinthefarnorth
# precrime
# predatingthehauntingofthelambertfamilyintheearliermoviesandrevealingmoremysteriesoftheotherworldlyrealmthefurther
# predator
# predatorarereleasedandbegintoterrorizethetown
# predictablelifeanddevelopsarebelliousalterego
# predictably
# predominantlythetwenty
# preferringthesimplelifeofafarmer
# prejudiceagainstfrankie
# prejudiceisahumorousstoryofloveandlifeamongenglishgentilityduringthegeorgianera
# prejudicesandpreconceptionsaboutthetrial
# prejudicewomandirectorabollywoodupdateofjaneausten
# preparestoretireafteronefinalrobbery
# preparetobattleattheinternationalbeattheworldcompetitionindetroit
# preparingtoexacthisrevenge
# present
# presentandfuture
# presentandfuturelifeofanyonewithwhomhecomesintophysicalcontact
# presentcommentaryringingoutoverthecountryside
# presentedinastylereminiscentofthesilentexpressionisticcinemaoftheearly20thcentury
# presentshadowwhomsheisdestinedtoface
# preservedintactbytheseclusionofthemountains
# presidentaddstothepressureofwinning
# presidentandrewshepherd
# presidentialhopefulandchildhoodhero
# presidentialnominee
# presidentoftheacademyoftobaccostudies
# presidentthomaswilsonthatthecrustoftheearthisbecomingunstableandthatwithoutproperpreparationsforsavingafractionoftheworld
# presidingoveratradeoligarchythatcontrolsallminingandsaleoficefromasteroidsandcomets
# presleychweneyagaejerrymofokengterryphetogavinhood
# pressedtodestroythesamurai
# pressedtowinwithoutacoach
# pressmanhassurmisedthatjeremiah
# prestonesq
# prestonwesleyjonathancoreygr
# presumeddead
# pretendingsheishisgirlfriendandtheywillsoonmarry
# pretendingthatronnieisagreatactorandthat
# previouslyofftargetwhenitcomestolove
# pricedlawyerritaintotakinghiscaseprobonoandinturnteachesherthevalueofloveandfamily
# prideandfaithhelphimfacetheoppressionofturn
# princeadonijah
# princeofdenmark
# princessavanthikaandlearnsthatherqueenhasbeenheldcaptiveforthelast25years
# princessida
# princesskasumiisanaristocraticwarriortrainedbymartial
# princesslessons
# princessodette
# princessofcrete
# principalofthirdstreet
# principledroseandsexyheather
# printable
# priortoherdeath
# priscilladiscoversthejoysofself
# prisonerscopjohnmcclane
# prisonforprofit
# prisonshavebeenturnedovertoamonolithicweylandcorporation
# privateinvestigatorboyfriendwhoencounterapairofserialkidnapperswhiletrailingamissingheirincalifornia
# privilegedtwenty
# priya
# priyawantsthemtoremainfriendsandsharpagrees
# probationaryfirefighterjackmorrisonmaturesintoaseasonedveteranatabaltimorefirestation
# problemis
# problems
# problemsariseandafeudensues
# problemsarisehoweverwhenthepolicedocomecallingandtheonetapethatcanprovehisinnocencehasmysteriouslydisappeared
# problemsarisewhentheduoismadeintoatriofollowingtheadditionofasexyfemaleperformer
# problemsarisewhenthekids
# proclaimedartistandgenius
# proclaimedbellesoftherock
# proclaimedvampirehunterandmagicianinthisremakeofthe1985comedy
# producedanarmyofmutantninjawarriors
# producedbyandstarringedwardburns
# producedbythebbc
# producednoexhaust
# producedonabudgetofjustover
# producer
# produceranilkapooranddirectorferozabbaskhanhaveshedlightontogandhitheperson
# producerjulianmarxfinallyfindsfundingfortheprojectfromgangsternickvalenti
# producinggangs
# productionofjuliuscaesarbecomesattractedtoacareer
# professional
# professionaldolphintrainer
# professions
# professorbrainardcreatesflubber
# professorlambeaumakesadealtogetleniencyforhimifhewillgettreatmentfromtherapistseanmaguire
# professormoriarty
# professoroxleyhasbeencapturedforhisknowledgeoftheskull
# profile
# profileclientinbeverlyhills
# profilemagazineinnewyork
# profitablescoregocomicallyawrywhenhegetsstuckinliverpoolwithanunlikelyescortandhisex
# program
# progressivepolitician
# prom
# prominentbutcurrentlyfailingstationinnewyorkcity
# promisedvisitfrommissie
# promisingfutureandromanceareturnedupside
# promisinglifetakeastartlingturnfortheworse
# promoter
# promptedbyhiscolleaguejeanne
# promptingafranticsearchforherpet
# promptingasmallbandofsurvivorstofightforthehumanraceinthissci
# promptingbroadcasteralmichaels
# promptingstiflertothrowtheultimatebachelorparty
# promptingthemtoreuniteandconfrontthereasonstheirliveswentsowrong
# promptingthemuppetstospringintoaction
# promptingthesiblingstoreturntoamericatoprepareforashowdownthefollowingyear
# promptingthespurnedgothgirltocastadarkspellontheswaggeringegotist
# promptingthetriotopulloffaharebrainedandmisguidedkidnappingscheme
# prone
# pronetofitsofblindbloodragebutsaddledwithacompunctionforhumans
# pronto
# proof
# proofofchrist
# proofplan
# proofprisons
# propaganda
# propelsherselfintoanimpossiblyriskysexualliaison
# propelshimfurtherawayfromhisfamily
# properties
# propertyofthehalf
# proposesthathissondelaystheirseparationprocessforfortydaysandfollowaprocedurecalled
# propriety
# prosecutedifshefindsandkillshim
# prospera
# protagonistandwifearenabbedatafutureusemigrationpointwithanillegalbabyduringpopulationcontrol
# protagonistfromthefreesearchgroupmakesemergencylandingonanunknownplanetwherehemuststay
# proteam
# protecthiscomrades
# protectingearthfromthescumoftheuniverse
# protectingthevalleyofpeacealongsidehisfriendsandfellowkungfumasters
# protectionandothers
# protectionprogram
# protectivechameleonandagruffgangofpubthugs
# protectthefiveplummerkidsfromenemiesoftheirrecentlydeceasedfather
# protectthesecretbehindhisspectacularant
# proudpatriarchabel
# provence
# providingbehind
# provingthatwhenyouwishuponastardreamsreallycancometrue
# prudence
# psychodramaalmostdisplacessexforshannonandgerard
# psychologicalperilandconstantthreat
# psychologicalstressdyinganddeatheditor
# psychologistcarolbennellandhercolleaguedr
# psychopathicparoleemr
# psychoticrapist
# publicizedice
# pubsandparties
# pulledapartineverydirection
# pullsintotroublewhenthey
# pullsoffanothersmoothandviolentarmoredcarheistinbroaddaylightinacrowdedstreet
# pulpfiction
# pulpfictiondeliversa
# pumped
# punctuatedwithasoundtrackthatmovesfrompulsatingdancetrackstohauntingkonkanisongs
# punishedforlovingeachother
# punishertaskforce
# punkcomputerhackernamedlisbethsalander
# purchasesalargehousethathasazoo
# pure
# purpledinosaurbarneysoonappearstoentertainkids
# purpose
# purposesontheblacksurfaceoflochness
# pursuedbyrussianspecialops
# pursuesaseriousrelationshipwithalong
# pursuinghimisateamofu
# pursuinghisdeterminationtouncoverthetruth
# push30milesbehindenemylinesandliberateover500americanprisonersofwar
# pushedbyhisambitiousmothertoseekthepositionofconsul
# pushedlimits
# pushesforhisparentstogetadivorce
# putaragtagsquadofcollegekidsupagainstthelegendaryjuggernautfromthesovietunionattheolympicgames
# putshimonthebadsideofcutthroatlocalbigshotbradwesley
# putshislifeandabusinesstriptochinaonholdwhenhethinksheseeslisa
# putsnewsuperweaponsindangeroushands
# putsthecarthroughitspacesontheroadtobecominganascarcompetitor
# putstheheroupagainsthisarchenemy
# puttheirfrustrationandangeraboutlifeinthemostdangerousplaceinamericaintothemostpowerfulweapontheyhad
# puttingatriskthelifeshethoughtshealwayswanted
# puttinghimonthefasttrackforapartnershipatthelawfirm
# puttingmankindingreaterdangerthanit
# puttingsidney
# putuporshutup
# pvt
# pymandlangmustplanandpulloffaheistthatwillsavetheworld
# qaedaterroristleaderosamabinladenaftertheseptember2001attacks
# qarrivesatschooltodiscoverthatmargo
# qiangzhangtarabirtwhistledavidmoroniguymaddin
# qijohnwoo
# qitonyleungka
# quaid
# quarantinedcountrytoretrieveacurebyanymeansnecessary
# quarterdancingclassstrikenorthernenglandscholarshipballetsetagainstthebackgroundofthe1984miner
# quarterreferencetospritechildastoryaboutfriendshipandloyalty
# quartetisahigh
# quasisoonfindshimselfbattlingtosavethepeopleandthecityheloves
# queen
# queenlatifah
# queenlatifahaliciasilverstoneandiemacdowellbillewoodruff
# queenlatifahcommonpaulapattonsanaahamri
# queenlatifahdollypartonkekepalmertoddgraff
# queenlatifahllcooljtimothyhuttonwaynewang
# queenofsparta
# queens
# questforfireexaminesapeacefultribe
# questioningherpastboyfriendsethan
# questioningtheirreligionsandbeliefs
# questions
# questtoqualifyforthe2012usolympictabletennisteam
# quick
# quicklygettingwayover
# quicklysetshersightsontheimpressionableben
# quickschemetoputontheworld
# quietlife
# quietlyenterstheirlives
# quietnewenglandtownwhenaman
# quietstella
# quigleyhitstheroad
# quincymccall
# quinn
# quinnmichaelwelchlaraflynnboyleduanejourney
# quintusdias
# quite
# quittingisnotanoption
# quoting
# quvenzhanéwallisdwighthenrylevyeasterlybenhzeitlin
# quvenzhanéwallisjamiefoxxrosebyrnewillgluck
# ra
# rabbijacobschramandfatherbrianfinnaredynamicandpopularyoungmenlivingandworkingonnewyork
# rabbit
# rabbitsuggesttiggergooutsideandfindothertiggerstobouncewith
# raceacrossthebeachtotheoceanbeforetheyarecapturedbyaseagullorcrab
# 
# raceandrockandrollin1950schicago
# racecarcrashpremonitiongorevisionafterayoungman
# racedaytonacarcrashtalentedbutunprovenstockcardrivercoletricklegetsabreakandwiththeguidanceofveteranharryhoggeturnsheadsonthetrack
# racefiguresinthetrial
# raceisanenthrallingfilmaboutcourage
# racerwhopartnerswitharichandarrogantbusinessassociate
# racesotheycan
# rachaelleighcooklukekirbykeithcarradineleonardfarling
# rachaelleighcookmatthewlillardrobertiscov
# rachaelleighcookrosariodawsontarareiddeborahkaplan
# rachel
# racheldratchhillelhalkinjasonkravitzjosephdorman
# rachelhasneverfeltmoreontheoutside
# rachelhendrixjasonburkeyrobertamayaandrewerwin
# rachelissureherdreamwillcometrue
# rachelmcadamschanningtatumsamneillmichaelsucsi
# rachelmcadamscillianmurphybriancoxwescraven
# rachelmcadamsharrisonfordpatrickwilsonrogermichel
# rachelmcadamsryangoslinggenarowlandsnickcassavet
# rachelmustdecidebetweenherstablerelationshipwithheckandherexhilaratingnewromancewithluce
# rachelnoticesluceintheaudienceandfeelsinstantlydrawntoher
# rachelunexpectedlyfallsintobedwithherlongtimecrush
# rachelweiszadrienbrodymarkruffalorianjohnson
# rachelweiszmarkwahlbergsusansarandonpeterjackson
# rachelweiszmaxminghellaoscarisaacalejandroamenábar
# racialaffairleadstoconfusionandnewideasforthetwounlikelylovers
# racialcousinmiklo
# rankingamericanofficer
# rankingcardinalrequeststhattherev
# rankingchurchofficialsandothersourcesdetail30yearsofeffortstoturnbackgayrights
# rankingjudge
# rankingofficialssuchasshadycol
# rankingpublicationwhenacorporatetakeoverresultsinhimbeingplacedundernaivesupervisorcarterduryea
# rankingswedishnoblemaniseducatedinamonasteryandsenttotheholylandasaknighttemplartodopenanceforaforbiddenlove
# raoulandjunior
# rapeandabusecasesledbyafemalejudge
# rapeciausapresidentwarveteranstagingfilmmakeralbaniasexscandalsenatorpresidentialelectiongulfwarmediaadvisermanipulationofthemediaelectioncampaigngovernmentwarsoldierextramaritalaffairduringthefinalweeksofapresidentialrace
# rapewhitehouseusapresidentdaughtergovernmentsuspensesecretservicesecretserviceagentamasterthiefcoincidentallyisrobbingahousewhereamurderinwhichthepresidentoftheunitedstatesisinvolvedoccursinfrontofhiseyes
# rapidlygrows
# rapmusic
# rapperchristopher
# rare
# rarely
# rarelyplayingbytherulesandhauntedbythedeathofhiswife
# rarevintagedollinapurewhiteweddingdress
# rascalflattsandvanessawilliams
# rashfindshismurderinvestigationoverwhelmedwithpotentialsuspects
# rashidajonesandysambergelijahwoodleetolandkrieg
# ratedcganimatedmovie
# ratedmoviefeaturingcanadiansterranceandphilip
# ratedvideogamesofalltime
# ratedwebsite
# rateguy
# ratemotelonastripofdesolatesuburbanbi
# ratevacationturnsintoanexaminationofthecommonproblemsmanyface
# rathdecidestotakeonelastjobandthenreturntocivilianlife
# ratherthangandhitheicon
# ratherthanreturntothetownimmediately
# ratherthanthebfg
# ratherthanworkingwithinthesystem
# raul
# ravishinglaila
# rawmahershalaaligaryross
# rawnateparkerminniedriverginaprince
# rawtalentandahomemadedemotape
# ray
# raycharleswentblindatseven
# raycopeswiththedespairandpovertyofhisneighborhoodbyusinghiswitsandverbaltalent
# raydiscoversthataliceledasecret
# raydokes
# rayelwoodisanamericansoldierstationedatagermanarmycamp
# rayheadstothefarmofhisoldfriendpeteculpepper
# rayhiresher
# rayincheonasquadofsoldiersfightinthekoreanwar
# rayjewelerfiancéeanewyorkgirlsetsherfatherupwithabeautifulwomaninashakymarriagewhileherhalfsistergetsengaged
# raykemeny
# rayliotta
# rayliottalaurenhollybrendangleesonrobertbutl
# rayliottallcooljmekhiphiferwaynebeach
# raymillandjanewymanphillipterrybillywild
# raymond
# raymondescapesfromthestatementalhospitalhe
# raymondmarble
# raymondochoajackbrightjeffreywrightpetersohn
# rayne
# rayneedstofindhisinvisiblemischievousmuttbeforetheydo
# rayreluctantlyteamsupwithlila
# rayromano
# rayromanogenehackmanmarciagayhardendonaldpetri
# rayromanojohnleguizamodenislearycarlossaldanha
# rayromanojohnleguizamodenislearychriswedg
# rayspendsmuchofhisfreetimecookingcocaineforthemps
# raystevensondominicwestjuliebenzlexialexand
# rayvisionrailgunu
# raywinstone
# raywinstoneangelinajolieanthonyhopkinsrobertzemecki
# raywinstonebendrewhayleyatwellnicklov
# raywinstonebenkingsleyianmcshanejonathanglaz
# raywinstoneronperlmanjasonconneri
# raywisejonathanbreckgarikayimutambirwavictorsalva
# razaaqadotisarahwaynecalliesmickeyrourkejetaamata
# raúljuliáanjelicahustonchristopherlloydbarrysonnenfeld
# reabouttoembarkontheadventureofalifetime
# reabouttoexperiencebothversions
# reabouttostaredownthemostterrifyingprospectofall
# reacherhimselfseesthenewsreportandturnsupinthecity
# reachersetsouttoconfirmforhimselftheabsolutecertaintyoftheman
# reachingconsequences
# reachingeffects
# reactuallynotalone
# readhotontheirheels
# readsherteenagedaughter
# readyandhisragtagcrewdescendonthetownoftemeculalikeapackofcoyotesonabasketfullofburgers
# readyisalloftheabove
# readytobeafathertohis13
# readytogooffatanymoment
# reaganmanagestoescapeandtakerefugeintheforest
# reaganwillneedallofherinnerstrengthandresourcefulnessinordertosurviveinthisgrippingthriller
# real
# realikable
# realisesshe
# realisingthattheoutofshapecrewwillbehard
# realistic3
# realittletooperfect
# reality
# realityandhypnoticsuggestionbegintoblur
# realitytrip
# realization
# realizationthatwhenthechipsaredown
# realizeshehasaresponsibilitytosavetheplanet
# realizesthathemustjoinwithhislifelongenemy
# realizesthathisyoungdaughteristalentedandbeginsperformingwithheratsmallvenues
# realizinghisone
# realizingthathewasselfishwithhisfriendandresponsibleforwhathappened
# realizingthattheyhavethetalentandresourcestomakesomethingoftheirlives
# realizingunsurpassedphysicalpotentialintheyoungboyhetrainshimintothemostdangerousmanalive
# reallandscapesthattransportsaudiencestotheprehistoricworldasitexisted70millionyearsago
# reallservingdetention
# realltrappedinamazethatwillrequirehimtojoinforceswithfellow
# reallyblurry
# realsotryingdesperatelytoescapepeoplewhohavemadethemtheirtargets
# reapingtheill
# reappearsafteranenigmaticabsenceof30yearstobecomethegreatestinternationalchallengetobothorthodoxscienceandprofessionalsceptics
# reback
# rebacktogether
# rebecca
# rebeccabecomesresentful
# rebeccahallcatherinekeeneramandapeetnicoleholofcen
# rebeccahalldominicwestimeldastauntonnickmurphi
# rebeccahallwillferrellglennhowertondanrush
# rebeccaromijnantoniobanderaspetercoyotebriandepalma
# rebeingfollowedbychanceacquaintancesthatsuspiciouslyfitthedescriptionofthekillers
# rebeingstalkedbyanevengreaterdanger
# rebelleaderprincessleia
# rebellion
# rebellioninmindanao
# rebetty
# reblack
# reboring
# rebornasthemotherfucker
# reborndoll
# rebothtransportedhalfwayacrossthecountrytheymustworktogethertogetbacktotheirnaturalhabitat
# reboundingfromhisfather
# rebuildhiscareer
# rec
# recallatimewhentheytradedpartners
# receiveasimplewoodenboxasagift
# receivesanunusualpresentfromhisyoungerbrother
# receivingamedalandapromotiontolieutenantforheroismduringhurricanekatrina
# receivingonlysilencefromthelocals
# recentlyawakenedpresidentstaton
# recentlydumpedbyhisgirlfriend
# recentlyreleasedfromamentalhospital
# recentlysprungfromjail
# rechosentobebackupsingersforthelegendaryjames
# recklesslyreignitesanancientwar
# recluse
# ...
# shemeetsintheairportbarjackrippner
# shemeetsmanycolorfulcharacterswhopopulatetheneighborhood
# shemeetspeter
# shemeetsstan
# shemeetsupwiththenutcrackerprince
# shemustbalanceherthirstforrevengewithherdesireforherfamilytoheal
# shemustconfrontthenakedtruth
# shemustcontendwithproblemsofherown
# shemustfollowthelastfootstepsofhersisterinordertocomeface
# shemustgetbacktothediner
# shemustjourneythroughthedarkestreachesoftheinstitute
# shemustleavewithherbestfriend
# shemustmakeachoicebetweencontinuingthelifeofasanfranciscoteenorsteppinguptothethrone
# shemustregainherfaithtocombattheevilthatwaitsinalouisianaswamp
# shemustwaithandandfootonhermother
# shemysteriouslygrowsto49
# shenanigan
# shenchman
# sheneedstheirhelp
# sheperformsaviolentcoupinwhichthekingismurderedandhisdaughter
# sheperseveres
# sheplanstofollowherlovertodublinandaskhimtomarryher
# shepromisestowritejohnoverseasuntilhereturns
# shepursuesthisdreamwithnothingbutambition
# shepushesforabilltobantestingonceandforall
# shequestionshismotivationsbutreluctantlyaccepts
# shequicklyfindsoutshemightbeonthewrongsideofright
# shequizzesrobert
# sheraidsthecityhablacandkillsthekeeperofatalismanthatgiveshergreatpower
# sherbuilding
# sherdreamtobeaprofessionaldancerandnowisherchance
# shereadsfashionmagazines
# sherealizesjusthowwidetheircommunicationgaphasgrown
# sherealizesthatdespiteherhappymarriagetoheck
# sherealizesthatshe
# sherealizesthatsheisseeingdeadpeople
# sherecruitsaformernewsjournalistandanchorwhodisapprovesofco
# sherecruitsstudentsfromdelhiuniversitytoactinherdocu
# sheredirectsherattentionstohisgeneral
# shereefakeelrobertgreenwald
# shereentersjakeandbrian
# sherefusestodivulgethenameofthefather
# sheregretsherpromise
# shereliesonherclimbingskillsandhelpfromhergeekyfriends
# shereluctantlyaccepts
# shereturnsthefavorbymellowingthehardnosedtycoon
# shereuniteswithherbestfriend
# sherfuneral
# sheriffsamdeedsunearthsmanyotherlong
# sherimoonzombiebrucedavisonjeffdanielphillipsrobzombi
# sherlockholmesanddoctorjohnwatsonbattletobringdownanewnemesisandunraveladeadlyplotthatcoulddestroyengland
# shermanbecomes
# shermangrowsdesperatetowhittlehis400
# shermanklump
# shero
# sherobattleagainstalieninvaders
# sheroes
# sheroicon
# sherotellsthelittle
# sherry
# sherunstohaddonfieldtogetdr
# sheseemstolikehim
# shesendshimaticket
# shesendsoliverabroadandtriestogatherevidenceoftheplotagainsther
# shesetsouttocapturetheonethatgotaway
# shesettlesinforwhatsheexpectstobeanordinaryevening
# shesimplymustserveaslillian
# sheslowlylearnswhatittakestobeatruebountyhunter
# sheslowlyrealizesherclientsharboraterrifyingsecret
# shesnaps
# shesoonattractstheattentionofanambitiousteenagernamedmax
# shesoonfindsherselffollowingmajorwilliamlarrabee
# shesoonfindsthatpeopleandeventsmaynotbewhattheyseemasshebecomesthetargetofanassassination
# shesoonrealizesjusthowdauntingthejourneywillbe
# shesparkswithsean
# shespiritsofftosanfranciscoinpursuitofherdreamsofarealculinarycareer
# shestartsdiggingarchivesandthroughsarah
# shestartsinvestigatingandsoonexposesamonumentalcover
# shestartsschoolandmeetsthereclusiveedwardcullen
# shestartsworkingasaprostitute
# shestaysandshegoestotheaudition
# shestayswithsomegangstersinmanderlayandtriestoinfluencethesituation
# shesubmitstoacorneatransplantation
# shetakesadramaticturnandblossomsintotheleaderoftheresistanceeffort
# shetakesajobinarestaurantandtriesunsuccessfullytodeveloprelationshipswithmen
# shetakesherfighttowashington
# shetakeshimtoapartyinthecountry
# shetakesoffonthecop
# shetakesthewomenofthegroupoutoftheircomfortzoneoftraditionalarrangementsandintoaworldofamazingharmoniccombinationsinafighttothetopofcollegemusiccompetitions
# shetalksayoungmanoutofsuicideandthenisplungedintoviolenceafterafriendlyencounterwithtwo
# sheteachesdanceclassesatanearbycommunitycenterinharlem
# shetellshimthatshedoesn
# shethenmeetsmichelleanddoesastompbattlewithher
# shethinksitisperfectuntileverythinggoesdownhillforthem
# shethinksshehasseenitall
# shethinksthatit
# shethoughtsheleftherchildhoodfearsbehind
# shetracksdownhisfavoritemusician
# shetriestobalanceanewromancewithmusicmanagerstix
# shetriestorecoverinherpresent
# shetriestostealherboyfriendwhoisamusicproducerbyofferingsexualfavors
# sheuncoversaworldofsecrets
# sheunderstandshorsesjustasmuchastheyunderstandher
# sheunknowinglyusestheunowntocreateherowndreamworldalongwithentei
# sheusesherpowerstomakehislifealivinghell
# shevisitseachofherformerassociatesone
# shevowstosabotagetheirrelationship
# shewaitsforhernextsessionwithderangedtherapistdr
# shewantsajob
# shewantstocelebratebutfindsonlythecompanyofheryoungassistant
# shewashisnumbertwowife
# shewasleadinganidylliclifeonkauai
# shewasneverreallysureofwhatwasandwasn
# shewillbecomearenownedartistandhealer
# shewillneverbewiththemansheloves
# shewindsupatthebrewer
# shewins
# shewitnessesfirsthandhowthenewiran
# shewondersifanotherworldlyspiritistryingtocontacther
# shewondersifshecansurvivetheircrazyantics
# shewoosquirkyscientistdr
# sheworksatafast
# sheworksforheruncleasahitmanbyday
# shewouldhavesoonbecomebreakfast
# shewouldknow
# shewouldnevercomplete
# sheydayasthedirectorof
# sheyearnsforamoreglamorouslifethanherbirthrightpromisesandresolvestoconquerenglishsocietybyanymeanspossible
# sheyearnstobe
# shh
# shialabeoufeldenhensonamysmartkylerankin
# shialabeoufjeffbridgeszooeydeschanelashbrannon
# shialabeoufjohnmalkovichkenjeongmichaelbay
# shialabeoufjoshduhamelmeganfoxmichaelbay
# shialabeoufmeganfoxjoshduhamelmichaelbay
# shialabeoufmichellemonaghanrosariodawsond
# shialabeoufsarahroemercarrie
# shialabeoufstephendillanejoshflitterbillpaxton
# shiddenpossessivedarkside
# shiddenragemakeshimatacklingmachinewhosebone
# shidingfromit
# shiftingalienthatassumestheappearanceofthepeoplethatitkills
# shiftingevents
# shiftingsandman
# shiftinventions
# shigh
# shighestmountain
# shimforherking
# shine
# shinealight
# shinerjin
# shinkim
# shinzon
# shinzonishuman
# shipbuilderwhohirestomtotraveltoitalytobringbackhisplayboyson
# shipownerthat
# shired
# shirleymaclainechristopherplummerchrisnothmichaelradford
# shirleymaclainejohnmcmartinricardomontalbanbobfoss
# shirleymaclainerickilakebrendanfraserrichardbenjamin
# shirleytemple
# shirleytemplespringbyingtonnigelbrucewalterlang
# shisbodysatanwilloccupy
# shisdream
# shisgoalforthesummertohelpsomeonegetintoheaven
# shislostlover
# shistory
# shisviolentboutsofparanoiaandjealousy
# shitao
# shitaohasgonemissinginthephilippineswherehehadbeenhelpinginanorphanage
# shitthejackpotwhenshemeetsahotshotdirector
# shividusetsofftorescueher
# shiwankhan
# shockedafteryearsspentchasingserialkillers
# shockedattheaccused
# shockedbythediscoveryofthisunknowntalent
# shockedbythisstrangenewenvironmentthatdoesn
# shockedintodisbelief
# shockingrelationshiptopicardhimself
# shockingrevelationsandpolicebrutality
# shoe
# sholdingapassportthatnobodyrecognizes
# sholdingawinninglotteryticketworth
# sholemaleichem
# sholemaleichemwasnotjustawitnesstothecreationofanewmodernjewishidentity
# sholidayisover
# sholiestrivers
# shome
# shomecomingofagegangjuveniledelinquentbasedonyoungadultnovelwhentwopoorgreasers
# shomedeathofachildorphanagesecretlovecrushchildrenfallinginloverelationshipwomandirectorpianoadramawithfairytaleelements
# shomedeathperfumejean
# shomeonenight
# shomeorphanagethiefviolencegoodandbadchildolivertwistthemodernfilmedversionofcharlesdickensbestseller
# shomeshoppingmallorphanagewinnebagochurchsunglassesparolecarchasemusicbandloudspeakersaturdaynightlivewrigleyfieldholidayinnjakebluesisjustoutofjail
# shoncollinsjasondavisashleyjohnsonchucksheetz
# shoneymoonisupendedbythearrivalsoftheirrespectivesisters
# shonor
# shootingfoursometosavetheday
# shootingonarentedboat
# shootsoutthestudio
# shopeofacontinuedbachelorhoodisinterruptedwhenhemeets12
# shopesofonceagainbecominga
# shopowner
# shopownerdanaandenglishmanseanmeetandfallinloveatfirstsight
# shopprostitutesexfortunetellerunderworldmurderprejudiceracismviolencepawnshopbipolardisorderseeminglymild
# shopshynessmontmartredaughtergardengnomejourneyroundtheworldphotographyatatinyparisiancafé
# shore
# shorrifiedtodiscoverthattheabductors
# shorrorclassic
# shorrorsliveonwhentheycomefacetofacewithabattalionofzombienazisoldiersintentondevouringanyoneunfortunateenoughtowanderintotheremotemountainswheretheywereoncesenttodie
# shorseridingdaysforever
# shortlyafterwardhefindshimselfstalkedbythekillerandissoondrawntoanoldhousewhereamysteriousladyinwhitelives
# shortlyintothetransatlanticjourneyfromnewyorktolondon
# shortlythereaftershegavebirthtojasmeet
# shortrest
# shoshanabushdamonwayansjr
# shospitalafterattackingherstepmotherandlosinghervoice
# shospitalbillsbyplayingonthesympathiesofthosewhorescuehimfromchokingtodeath
# shot
# shotatsevendifferentshows
# shotel
# shotfederalprosecutoronthecuspofabrightpoliticalfuture
# shotgun
# shotonlocationinnewyork
# shotrightinthemidstoftheteeminginternationaltouristhotspots
# shottestmodelingagencies
# shouldbeenjoyingthetimeofherlife
# shouldbewellonhiswaytoasuccessfulcareeratafortune500company
# shouldhuntchoosetoacceptit
# shouldsheleavehome
# shouldtheyfailorrefusetocooperate
# shouse
# shouseandaccidentallyknocksoveratop
# shouseanddon
# shouseastheirownmembersonlyclubhouse
# shouseevolvinglittleredhidinghood
# shousehiswholelife
# shouseinthecountry
# shouseinthecountryarehuntedandterrorizedbyachain
# shouseisnowamuseumhonouringguillermogaribai
# shouseontheway
# shousetogetinsidethehouseandretrievethediamond
# shousewiththeprizemoney
# showfreak
# showhost
# showhostleonphelps
# showingabeautifulandeccentricheiressthetimeofherlifewitharomanticadventurethattakesthemaroundtheworld
# thewolf
# theworkandtheglory
# theworld
# thex
# theydo
# theydon
# theyfallinlove
# thirty
# thistime
# thistimearound
# thoughhe
# threemen
# thrilling
# tibet
# tigress
# time
# tobeymaguirekirstendunstjamesfrancosamraimi
# tobinbellcostasmandylorbetsyrussellkevingreutert
# today
# todd
# tofindher
# tolkien
# tom
# tomakemattersworse
# tommy
# tommyleejones
# tony
# tonyleungchiu
# tora
# torescuehim
# tosaveearth
# tosaveher
# tothisend
# tough
# tracy
# trent
# troy
# true
# trust
# turned
# twohitmen
# ultimately
# unbreakable
# uncle
# unfortunately
# untilnow
# urbanlegends
# viola
# violence
# viperandmonkey
# vivicaa
# wai
# walter
# walteranddanny
# wanda
# wantsitall
# war
# ward
# washington
# way
# west
# whattheydidn
# whendr
# whenhe
# whentragedystrikes
# wherehe
# wherethey
# white
# whitmoreii
# whodoesn
# whodon
# whohas
# whohasseizedcontrolofgotham
# wife
# willemdafoe
# willferrelljohnc
# williamh
# williamshatnerleonardnimoydeforestkelleyleonardnimoy
# williamshatnerleonardnimoydeforestkelleynicholasmey
# wook
# woon
# worker
# workers
# working
# world
# wurmfeld
# year
# yearold
# yearoldson
# yearslater
# yetcriticalattitudeinfusesthedramawithapainfulpowerthatfinallyeruptsinadevastatingandthrilllingconclusion
# young
# zacefron
# zacefronvanessahudgensashleytisdalekennyortega
# zambezia
# zebra
# zombies
# zooeydeschanel

# %%
vectors[0].shape
# Out:
# (5000,)

# %%
# used coine similarity to find distances between the vectors
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
similarity.shape
# Out:
# (4800, 4800)

# %%
# distance of film Avatar to other films in the list. values close to 1 being the most similar and 0 being least similar.
distance = (similarity[final_df[final_df['title'] == 'Avatar'].index[0]])
distance
# Out:
# array([1.        , 0.08346223, 0.0860309 , ..., 0.04499213, 0.        ,
#        0.        ])

# %%
# need to sort the distance list above to find the 5 most similar films.
# need to retain the original index from the distance list(enumerate will help), then sort. example below. 
# key function helps to sort according to the 2nd value of the enumerate tuple. then slice top 5.

sorted(list(enumerate(similarity[0])), reverse=True, key=lambda x: x[1])[1:6]
# Out:
# [(1214, 0.28676966733820225),
#  (2405, 0.26901379342448517),
#  (3724, 0.2605130246476754),
#  (507, 0.255608593705383),
#  (539, 0.25038669783359574)]

# %%
new_movies_df.iloc[1214]
# Out:
# id                                                        440
# title                             Aliens vs Predator: Requiem
# genres      [Fantasy, Action, ScienceFiction, Thriller, Ho...
# keywords    [predator, nationalguard, hybrid, alien, morgu...
# overview    [A, sequel, to, 2004's, Alien, vs., Predator,,...
# cast             [StevenPasquale, ReikoAylesworth, JohnOrtiz]
# crew                                           [ColinStrause]
# tags        [Fantasy, Action, ScienceFiction, Thriller, Ho...
# Name: 1216, dtype: object

# %%
def recommend(movie):
    movie_index = final_df[final_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x: x[1])[1:6] 
    for i in movies_list:
        print(new_movies_df.iloc[i[0]]['title'])

# %%
recommend('Batman Begins')
# Out:
# The Dark Knight
# Batman
# Batman
# The Dark Knight Rises
# 10th & Wolf

# %% [markdown]
# # Import the functions as pickle file for streamlit

# %%
import pickle

# %%
pickle.dump(final_df.to_dict(), open('movies_dict.pkl', 'wb'))

# %%
pickle.dump(similarity, open('similarity.pkl', 'wb'))
